# %% [markdown]
# # Chapter 5: Unveiling the Mystery of Variables and Expressions
#
# ## 1. If x = 7, what is the value of 2x + 3?
#  2(2) + 3 = 4 + 3 = 7
#   x =7
#
# ### 2. Simplify the expression 4x – 2x + x.
#
#  4x – 2x + x.
#     2x + x
#     3x
#     Answer: The simplified form of the given expression is 3x.
#
# ### 3. Solve the one-step equation x/4 = 3.
#    (x/4) * 4 = 3 * 4
#    x = 3*4
#    x = 12
#
#  ### 4.   Find x in the two-step equation 3x – 4 = 11.
#    3x – 4 = 11
#    3x = 11+4
#    3x/3 = 15/3
#     OR
#    x = 15/3
#    x = 5
#
# ### 5. Solve the multi-step equation 2(x + 3) + 4x = 24.
#    2(x + 3) + 4x = 24
#    2x + 6 + 4x = 24
#   6x + 6 = 24
#     6x = 24 -6
#     6x = 18
#     x = 18/6
#     x = 3
#
# ### 6. Graph the inequality 2x + 3 > 7 on a number line.
#
#    2x +3 >7
#    solve the inequality:
#    2x > 7 -3
#    2x > 4
#    x > 2
#    o-----o-----o-----o-----o-----o-----o
#               -∞    -1     0     1     2     3     +∞
#
# ### 7. Solve the compound inequality 4 < 2x + 1 < 10.
#
#    compound inequality consists of two parts:
#    4 < 2x + 1
#    2x + 1 < 10
#
#    solve them separatetly:
#
#    4 - 1 < 2x + 1 -1
#    3 < 2x
#    3/2 < x
#
#    Now 2x + 1 < 10
# Subtracting 1 from both sides:
#
# 2x + 1 -1 < 10 -1
# 2x < 9
# x< 9/2
#
# Now 3/2 , 9/2 Ans.
#
# ### 8. What is the coefficient of y in the expression 3x + 4y – 5?
#    The coefficient of y in the expression 3x + 4y - 5 is 4.
#
# ### 9. Combine like terms: 5a + 2b – 3a + 4.
#
# 5a - 3a = (5 - 3)a = 2a
# 2a + 2b + 4
#
# ### 10. Isolate x in the equation 2x – 5 = 3x + 7.
#
# 2x -3x =x
# x = 7 + 5
# x = 12
