# %% [markdown]
# # Chapter 1:
#
# ### 1 .Understanding the Basics Identify the smallest natural number.
#
# Sol: The smallest natural number 1.
#
# ### 2 .Write the next five whole numbers after 17.
#
# Sol: 18, 19 ,20, 21, 22
#
# ### 3. List all integers between -3 and 3.
#
# Sol: -3, -2, -1, 0, 1, 2, 3
#
# ### 4. Express the fraction 3/4 as a rational number.
#
# Sol: The number 3/4 is rational because it represents one divided by two.
#
# ### 5. Is the square root of 2 a rational or an irrational number?
#
# Sol: The square root of 2 is an irrational number.
#
# ### 6. Solve the arithmetic operation: 8 × (3 + 5) ÷ 2 – 6.
#
# Sol: 8 × (3 + 5) ÷ 2 - 6
#     =8 * 8 / 2 -6
#     = 64/2-6
#     = 32-6
#     = 26 Ans
# ### 7. If x = 5, evaluate the expression 2x + 3.
#
# Sol: 2x + 3
#     = 2(5) + 3
#     = 10 + 3
#     = 13 Ans.
#
# ### 8.Simplify the equation 2(x – 3) + 4 = 0 and find x.
#
# Sol:2(x – 3) + 4 = 0
#     2X- 6 + 4 = 0
#     2x -2 = 0
#       x = 0
#
# ### 9. Graph the inequality y < 2x + 1 on a coordinate plane.
#
# Sol: When x = 0, y = 2(0) + 1 = 1. So we have the point (0, 1).
# When x = 1, y = 2(1) + 1 = 3. So we have the point (1, 3).
#
# ### 10. What is the value of the expression 3^2 + 4^2?
#
# Sol: 3^2 + 4^2
#      3^2 = 3 * 3 = 9
#      4^2 = 4 * 4 = 16
#      9 + 16 = 25
#
# ### 11. Calculate the absolute value of -15.
#
# Sol:  The absolute value of -15 is 15.
#
# ### 12. The reciprocal of 1/2 is found by flipping the fraction, resulting in 2/1 or simply 2.
#
# Sol: The reciprocal of 1/2 is 2.
#
# ### 13. Perform the operation: 7 − (−2) + 3.
#
# Sol: 7 + 2 = 9
#      9 + 3 = 12
# ### 14. Find the product of −4 and 6.
#
# Sol: -4 * 6 = -24
#
# ### 15. Determine if the number 0.333… is rational or irrational.
#
# Sol:  The number 0.333... is rational.
