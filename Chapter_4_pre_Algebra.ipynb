# %% [markdown]
# # Chapter 4: Mastering the Art of Percentages
#
# ### 1. Convert the fraction 3/5 to a percentage.
#    3/5 * 100 = (3 * 100) / 5 = 300/5 = 60
#    the fraction 3/5 is equivalent to 60%.
#
# ### 2. Change 40% to a decimal.
#    40% = 40/100 = 0.4
#
# ### 3. What is 25% of 200?
#  25% of 200
#  25/100 * 200= 50
#
# ### 4. If a dress costs $70 after a 30% discount, what was the original price?
#
# The original price as "x".
# After a 30% discount, the discounted price is 70 dollars, which is equal to 70% of the original price.
# 70% of x = $70
# 0.70x = $70
# x = $70 / 0.70
# x = $100
# The original price of the dress was $100.
#
# ### 5. A population of 50,000 increases by 5% per year. What is the population after one year?
#    5% = 5/100 = 0.05
#    The increase in population over one year is 0.05*50000 = 2500 people.
#    So, the population after one year would be 50000 + 2500 = 52500.
#
# ### 6. Calculate the percentage decrease if a product’s price drops from $200 to $150.
#    $200 - $150/$200 *100= 25%
#
# ### 7. Find 150% of 60.
#  150/100 = 1.5 * 60 = 90
#
# ### 8.What percentage of a day is 6 hours?
#
#   To find the percentage, we can set up a proportion:
#    6 hours / 24 hours = x / 100%
#    To find the percentage, we can set up a proportion
#     6/24,  x/100
#     600 = 24x
#     600/24 = x/24 OR
#     x = 600/24
#     x = 25
#
# ### 9. If you save $20 on a $50 item, what percent discount is that?
#    Percent discount = ($20 / $50) * 100 = 40%
#
#  ### 10. A score of 80% is needed to pass a test. If the test has 50 questions, how many questions must you answer correctly?
#   80% is equivalent to 0.8 as a decimal.
#   80/100 = 0.8
#   0.8 *50 =  40
#   At least 40 questions correctly in order to pass the test.
